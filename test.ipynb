# %%
import modals
import modals.columns
import modals.db
db = modals.db.DataBase("apdfs")
# columns_map = {"id": modals.columns.Column("id", 1, False),"name":modals.columns.Column("name", 2, False),"job":modals.columns.Column("job",2,False),"age":modals.columns.Column("age", 1, False),"is_cool":modals.columns.Column("is_cool", 1, False)} 
# columns_list =columns_map.keys()
# table = db.create_tables("test5", columns_list, columns_map)
# Out:
# Path already exists!
# ...

# %%
table = db.tables['test5']

# %%
table.columns
# Out:
# {'id': <marshaller.colmarshal.Column at 0x76d89ad0c050>,
#  'name': <marshaller.colmarshal.Column at 0x76d89b6e9e50>,
#  'job': <marshaller.colmarshal.Column at 0x76d89b6e9d10>,
#  'age': <marshaller.colmarshal.Column at 0x76d89b64dcd0>,
#  'is_cool': <marshaller.colmarshal.Column at 0x76d89b64de00>}

# %%
import random

for i in range(100):
    record = {'id':random.randint(a = 10,b = 1000), 'name':"Shreyank", 'job':"randomguy", 'age':3, 'is_cool':4}

    table.insert(record)
# Out:
# Encoded TLV: [5, 4, 0, 0, 0, 230, 3, 0, 0] for value 998
# Encoded TLV: [2, 8, 0, 0, 0, 83, 104, 114, 101, 121, 97, 110, 107] for value Shreyank
# Encoded TLV: [2, 9, 0, 0, 0, 114, 97, 110, 100, 111, 109, 103, 117, 121] for value randomguy
# Encoded TLV: [5, 4, 0, 0, 0, 3, 0, 0, 0] for value 3
# Encoded TLV: [5, 4, 0, 0, 0, 4, 0, 0, 0] for value 4
# Encoded TLV: [5, 4, 0, 0, 0, 230, 3, 0, 0] for value 998
# Encoded TLV: [2, 8, 0, 0, 0, 83, 104, 114, 101, 121, 97, 110, 107] for value Shreyank
# Encoded TLV: [2, 9, 0, 0, 0, 114, 97, 110, 100, 111, 109, 103, 117, 121] for value randomguy
# Encoded TLV: [5, 4, 0, 0, 0, 3, 0, 0, 0] for value 3
# Encoded TLV: [5, 4, 0, 0, 0, 4, 0, 0, 0] for value 4
# Encoded TLV: [5, 4, 0, 0, 0, 137, 0, 0, 0] for value 137
# Encoded TLV: [2, 8, 0, 0, 0, 83, 104, 114, 101, 121, 97, 110, 107] for value Shreyank
# Encoded TLV: [2, 9, 0, 0, 0, 114, 97, 110, 100, 111, 109, 103, 117, 121] for value randomguy
# ...

# %%
table.select()
# Out:
# Decoded TLV: type=5, length=4, value=425
# Decoded TLV: type=2, length=8, value=Shreyank
# Decoded TLV: type=2, length=9, value=randomguy
# Decoded TLV: type=5, length=4, value=3
# Decoded TLV: type=5, length=4, value=4
# Decoded TLV: type=5, length=4, value=842
# Decoded TLV: type=2, length=8, value=Shreyank
# Decoded TLV: type=2, length=9, value=randomguy
# Decoded TLV: type=5, length=4, value=3
# Decoded TLV: type=5, length=4, value=4
# Decoded TLV: type=5, length=4, value=781
# Decoded TLV: type=2, length=8, value=Shreyank
# Decoded TLV: type=2, length=9, value=randomguy
# Decoded TLV: type=5, length=4, value=3
# Decoded TLV: type=5, length=4, value=4
# Decoded TLV: type=5, length=4, value=18
# Decoded TLV: type=2, length=8, value=Shreyank
# Decoded TLV: type=2, length=9, value=randomguy
# Decoded TLV: type=5, length=4, value=3
# Decoded TLV: type=5, length=4, value=4
# Decoded TLV: type=5, length=4, value=822
# Decoded TLV: type=2, length=8, value=Shreyank
# ...

# %%
record['id'] = 3
r = table.delete(wherestmt={'id':[i for i in range(100)]})
# Out:
# ['id', 'name', 'job', 'age', 'is_cool']
# Decoded TLV: type=5, length=4, value=3
# Decoded TLV: type=2, length=8, value=Shreyank
# Decoded TLV: type=2, length=9, value=randomguy
# Decoded TLV: type=5, length=4, value=3
# Decoded TLV: type=5, length=4, value=4
# 1 to the rawrecords
# Decoded TLV: type=5, length=4, value=3
# Decoded TLV: type=2, length=8, value=Shreyank
# Decoded TLV: type=2, length=9, value=randomguy
# Decoded TLV: type=5, length=4, value=3
# Decoded TLV: type=5, length=4, value=4
# 1 to the rawrecords
# Decoded TLV: type=5, length=4, value=3
# Decoded TLV: type=2, length=8, value=Shreyank
# Decoded TLV: type=2, length=9, value=randomguy
# Decoded TLV: type=5, length=4, value=3
# Decoded TLV: type=5, length=4, value=4
# 1 to the rawrecords
# Decoded TLV: type=5, length=4, value=3
# Decoded TLV: type=2, length=8, value=Shreyank
# Decoded TLV: type=2, length=9, value=randomguy
# Decoded TLV: type=5, length=4, value=3
# Decoded TLV: type=5, length=4, value=4
# ...

# %%
r
# Out:
# 114

# %%
table.select(wherestmt={'id':[i for i in range(100)]})
# Out:
# ['id', 'name', 'job', 'age', 'is_cool']
# No records found
# []
